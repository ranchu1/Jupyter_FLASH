# %% [markdown]
# Ref: Yahil, A. (1983). Self-similar stellar collapse. The Astrophysical Journal, 265, 1047. https://doi.org/10.1086/160746
#
# Self-similar stellar collapse
# EOS:

# %%
# import library
# %matplotlib inline
import rclib.IO as rcIO # make sure the lib is linked to the same directory
import rclib.plot as rcplt
import rclib.Scale as rcscale
import rclib.Analytical_Yahil as rcyahil

import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# data in
[ time, coord_fined, dens_1dx, velx_1dx ] \
= rcIO.test_FLASH_IO_convert2_1D( '', 'yahil1d_hdf5_chk_', 51, 'nodescribe' )
# Out:
# filename = yahil1d_hdf5_chk_0051
# time = 0.05100106526953094  s
# geometry = b'spherical                                                                       '
# gr_titleszex 8
# [nxb, nyb, nzb] = [ 8 1 1 ]
# size coord_fined (20880, 1)

# %%
ctr_pres = 6.e27
ctr_rho  = 7.e9
int_gamm = 1.33
kappa = ctr_pres / pow(ctr_rho, int_gamm)
#pres_a = rcyahil.analytical_yahil_k_r_g(kappa,dens_1dx,int_gamm)
dens_a = rcyahil.analytical_yahil_k_r_g_t(kappa,dens_1dx,int_gamm, time)
print(kappa)
# Out:
# 483248881117108.56

# %%
# make plot: dens vs r; pre vs r
fig=plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')
ax1 = plt.subplot(121)
plt.loglog(coord_fined* 1e-5,dens_1dx,'.')
#plt.loglog(coord_fined* 1e-5,2*dens_1dx,'.')
plt.xlim((1e0, 1e4))
plt.ylim((1e5, 1e15))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Mass Density [g/cm3]',fontsize=16)
ax1.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
ax1.set_title('-t [ms] = %f'%(150-time*1e3), fontsize=20)
ax2 = plt.subplot(122)
plt.semilogx(coord_fined* 1e-5,velx_1dx/(3e10),'.')
plt.xlim((1e1, 1e5))
plt.ylim((-0.15, 0.01))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Velocity [c]',fontsize=16)
ax2.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
plt.subplots_adjust(bottom=0.25, top=0.75)
plt.show()

# %%
# data in
[ time, coord_fined, dens_1dx, velx_1dx ] \
= rcIO.test_FLASH_IO_convert2_1D( '', 'yahil1d_hdf5_chk_', 135, 'nodescribe' ) 
# make plot: dens vs r; pre vs r
fig=plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')
ax1 = plt.subplot(121)
plt.loglog(coord_fined* 1e-5,dens_1dx,'.')
plt.xlim((1e0, 1e4))
plt.ylim((1e5, 1e15))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Mass Density [g/cm3]',fontsize=16)
ax1.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
ax1.set_title('-t [ms] = %f'%(150-time*1e3), fontsize=20)
ax2 = plt.subplot(122)
plt.semilogx(coord_fined* 1e-5,velx_1dx/(3e10),'.')
plt.xlim((1e1, 1e5))
plt.ylim((-0.15, 1.15))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Velocity [c]',fontsize=16)
ax2.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
plt.subplots_adjust(bottom=0.25, top=0.75)
plt.show()

# %%
# data in
[ time, coord_fined, dens_1dx, velx_1dx ] \
= rcIO.test_FLASH_IO_convert2_1D( '', 'yahil1d_hdf5_chk_', 145, 'nodescribe' ) 
# make plot: dens vs r; pre vs r
fig=plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')
ax1 = plt.subplot(121)
plt.loglog(coord_fined* 1e-5,dens_1dx,'.')
plt.xlim((1e0, 1e4))
plt.ylim((1e5, 1e15))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Mass Density [g/cm3]',fontsize=16)
ax1.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
ax1.set_title('-t [ms] = %f'%(150-time*1e3), fontsize=20)
ax2 = plt.subplot(122)
plt.semilogx(coord_fined* 1e-5,velx_1dx/(3e10),'.')
plt.xlim((1e1, 1e5))
plt.ylim((-0.15, 1.15))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Velocity [c]',fontsize=16)
ax2.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
plt.subplots_adjust(bottom=0.25, top=0.75)
plt.show()

# %%
# data in
[ time, coord_fined, dens_1dx, velx_1dx ] \
= rcIO.test_FLASH_IO_convert2_1D( '', 'yahil1d_hdf5_chk_', 149, 'nodescribe' ) 
# make plot: dens vs r; pre vs r
fig=plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')
ax1 = plt.subplot(121)
plt.loglog(coord_fined* 1e-5,dens_1dx,'.')
plt.xlim((1e0, 1e5))
plt.ylim((1e0, 1e15))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Mass Density [g/cm3]',fontsize=16)
ax1.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
ax1.set_title('-t [ms] = %f'%(150-time*1e3), fontsize=20)
ax2 = plt.subplot(122)
plt.semilogx(coord_fined* 1e-5,velx_1dx/(3e10),'.')
plt.xlim((1e1, 1e5))
plt.ylim((-0.15, 1.15))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Velocity [c]',fontsize=16)
ax2.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
plt.subplots_adjust(bottom=0.25, top=0.75)
plt.show()

# %%
# data in
[ time, coord_fined, dens_1dx, velx_1dx ] \
= rcIO.test_FLASH_IO_convert2_1D( '', 'yahil1d_hdf5_chk_', 150, 'nodescribe' ) 
# make plot: dens vs r; pre vs r
fig=plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')
ax1 = plt.subplot(121)
plt.loglog(coord_fined* 1e-5,dens_1dx,'.')
plt.xlim((1e0, 1e5))
plt.ylim((1e0, 1e15))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Mass Density [g/cm3]',fontsize=16)
ax1.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
ax1.set_title('-t [ms] = %f'%(150-time*1e3), fontsize=20)
ax2 = plt.subplot(122)
plt.semilogx(coord_fined* 1e-5,velx_1dx/(3e10),'.')
plt.xlim((1e1, 1e5))
plt.ylim((-0.15, 1.15))
plt.xlabel('Radius [km]',fontsize=16)
plt.ylabel('Velocity [c]',fontsize=16)
ax2.tick_params(direction='out', length=6, width=2, colors='k',
               grid_color='k', grid_alpha=0.5,labelsize = 16)
plt.subplots_adjust(bottom=0.25, top=0.75)
plt.show()
