# %%
import rclib.IO as rcIO # make sure the lib is linked to the same directory
import rclib.plot as rcplt
import rclib.Scale as rcscale
import numpy as np

# %%
[block_size, coordinates, bounding, veltot, dens, pres ]= \
rcIO.test_FLASH_IO( '', 'yahil_hdf5_chk_', 13 )
                                                                    
print(veltot.shape)
veltot[1][0][1][1]
print('block_size', block_size.shape)
block_size[1][1]
print('dens ', dens.shape)
dens1 = dens[:,0,:,:]
print('dens1 ', dens1.shape)
dens1[0,:,:]
print('size veltot', veltot.shape)
# Out:
# filename = yahil_hdf5_chk_0013
# (8522, 1, 8, 8)
# block_size (8522, 3)
# dens  (8522, 1, 8, 8)
# dens1  (8522, 8, 8)
# size veltot (8522, 1, 8, 8)

# %%
r = rcscale.scale_FLASH_2DCylindrical_Coordinate( coordinates )
dens_1d = rcscale.scale_FLASH_2DCylindrical( dens )

rcplt.plot_1Ddot(r,dens_1d)
# Out:
# var    shape  (8522, 1, 8, 8)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)
plt.colorbar();

# %%
rng = np.random.RandomState(0)
block_size3D = block_size[:,0] * block_size[:,1] / block_size[0,0] / block_size[0,1] * 100
plt.scatter(coordinates[:,0], coordinates[:,1], marker="s", c=dens_1d, s= block_size3D, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale
plt.gca().set_aspect('equal', adjustable='box')
